# %% [markdown]
# ## Test REST-api
# * this [Notebook]()
# * [nvpub.vic-metria.nu/friluftsliv](http://nvpub.vic-metria.nu/friluftsliv/ui/index.html#/LedService/find2)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2022-09-20 17:45:13.042474

# %%
url= "http://nvpub.vic-metria.nu/friluftsliv/rest/led/"
header ="accept: text/plain;charset=utf-8"
import urllib3, json
import pandas as pd 

http = urllib3.PoolManager()
r = http.request(
    'GET',
    url,
    headers={
        "accept": "application/json"
    })

print(r.status)
data = json.loads(r.data.decode('utf-8')) 
#print(type(data))
print(r.info())
# Out:
# 200
# HTTPHeaderDict({'Date': 'Tue, 20 Sep 2022 20:06:49 GMT', 'Server': 'Apache/2.4.54 (Unix) OpenSSL/1.1.1q', 'Content-Type': 'application/json;charset=utf-8', 'Access-Control-Allow-Origin': '*', 'Transfer-Encoding': 'chunked'})

# %%
from flatten_json import flatten
dftot = pd.json_normalize(data)  
dftot
# Out:
#     led.did                                    led.beskrivning  \
# 0    528278  En transportsträcka ner till stranden, där man...
# 1    434715                                                NaN
# 2    435430                                                NaN
# 3    437029  Vandringsled i bokskog. Stigen är inte uppgrus...
# 4    531203                                                NaN
# ..      ...                                                ...
# 95   435787                                                NaN
# 96   455849                                                NaN
# 97   436765                                                NaN
# 98   443437                                                NaN
# 99   435553                                                NaN
#
#     led.externpublicering    led.id  \
# 0                       1  30528278
# 1                       1  30218829
# 2                       1  30218135
# 3                       1  30424210
# 4                       1  30531203
# ..                    ...       ...
# 95                      1  30373221
# 96                      1  30455849
# 97                      1  30417846
# 98                      1  30443437
# 99                      1  30364123
#
#                                   led.ledmarkering                led.ledNamn  \
# 0    Blåvita ridledsbrickor på ekstolpar 90x90 mm.            Ridtransportled
# 1                                  Ingen markering     Stig runt vattenfallet
# 2                                              NaN                Grottstigen
# 3   Ekstolpar ca 45x45 mm med blå fyrkantig bricka                 Blå slinga
# 4                                              NaN                        NaN
# ..                                             ...                        ...
# 95                                             NaN  Urskogsstigen Marsfjället
# 96                                            Röse                        NaN
# 97                                             NaN                        NaN
# 98                                             NaN                        NaN
# 99                                             NaN        Gångstig från Skeer
#
#                                         led.atom.link
# 0   [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 1   [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 2   [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 3   [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 4   [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# ..                                                ...
# 95  [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 96  [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 97  [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 98  [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
# 99  [{'@rel': 'LedLedtyp', '@href': 'http://nvpub....
#
# [100 rows x 7 columns]

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   led.did                100 non-null    int64
#  1   led.beskrivning        13 non-null     object
#  2   led.externpublicering  100 non-null    int64
#  3   led.id                 100 non-null    object
#  4   led.ledmarkering       48 non-null     object
#  5   led.ledNamn            53 non-null     object
#  6   led.atom.link          100 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB

# %%
pd.set_option('display.max_rows', 500)
dftot["led.ledNamn"]
# Out:
# 0                                       Ridtransportled
# 1                                Stig runt vattenfallet
# 2                                           Grottstigen
# 3                                            Blå slinga
# 4                                                   NaN
# 5                                                   NaN
# 6                                    Vandringsstig 800m
# 7                 Rundslinga Vandringsled - Torparudden
# 8                                                   NaN
# 9                                                   NaN
# 10                                  Stig till fågeltorn
# 11                                  stig till vindskydd
# 12                                                  NaN
# 13                                 Stig till reservatet
# 14                    Båttrafikled Ytte Bodane inomskär
# 15                                      Baldersnäs stig
# 16                                           Gruvrundan
# 17                                 Stig till Gammelhamn
# 18                                   Västra Vätterleden
# 19                                            Svart led
# 20                                                  NaN
# 21                                           Bruksleden
# 22                                           Blå slinga
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                       Sjövik vandringsled med utsikt
# 30                                                  NaN
# 31                                 Vandringsstig Ramsön
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                 Led till kalkbrottet
# 36                                                 Stig
# 37                                              Blå Led
# 38           Vandringsleden Bruksleden genom Jättåsarna
# 39                                                  NaN
# 40                    Vandringsled (Längd: 1 kilometer)
# 41                                         Vandringsled
# 42                                   Grimmestorpsrundan
# 43                                                  NaN
# 44                  Vandringsled (Längd: 1,4 kilometer)
# 45                                                  NaN
# 46                                                  NaN
# 47                                Seljebågen Kockholmen
# 48                                         Östkustleden
# 49                                                 Stig
# 50                                                  NaN
# 51                                   Utsiktsnipans stig
# 52                                                  NaN
# 53                                                  NaN
# 54                                                  NaN
# 55                                                  NaN
# 56                                                  NaN
# 57                                                  NaN
# 58          Sommarled till Stora Kullerberget från norr
# 59                                                  NaN
# 60                                                  NaN
# 61                                 Led Dundern, torpled
# 62                                      Hovetvandringen
# 63                                                  NaN
# 64                                                  NaN
# 65                              Vandringsled cirka 5 km
# 66                                         Vandringsled
# 67                                                  NaN
# 68                                                  NaN
# 69                                                  NaN
# 70                               Stigsystem Rövarekulan
# 71                               Väg Trossö-Kalvö-Lindö
# 72                                                  NaN
# 73    Vandringsstig Abborrtjärnen till Lill-brännträ...
# 74                                                  NaN
# 75                                                 Stig
# 76                                Blå slinga Mickelskog
# 77                                            Led Tegen
# 78                       Vandringsled Blecktjärnsskogen
# 79                                                  NaN
# 80                                          Stig Skålen
# 81                                          Led Sillnäs
# 82                                          Skåneleden
# 83                                                  NaN
# 84                                             Gångstig
# 85                         Ormlångenskogen vandringsled
# 86                        Handikappled till utsiktplats
# 87                                    Del av Skåneleden
# 88                                                  NaN
# 89                                                  NaN
# 90                                                  NaN
# 91                                                  NaN
# 92                                                  NaN
# 93                                         Penåsa ödeby
# 94                                                  NaN
# 95                            Urskogsstigen Marsfjället
# 96                                                  NaN
# 97                                                  NaN
# 98                                                  NaN
# 99                                  Gångstig från Skeer
# Name: led.ledNamn, dtype: object
